# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import pandas as pd

# %%
options = webdriver.ChromeOptions()
options.add_argument('--headless')
options.add_argument('--no-sandbox')
options.add_argument('--disable-dev-shm-usage')

# %%
site = 'http://tsmarketing.in/DailyArrivalsnPricesCommoditywise.aspx'

# %%
wd = webdriver.Chrome('chromedriver',options=options)
wd.get(site)

# %%
html = wd.page_source

# %%
df = pd.read_html(html)

# %%
df[0][:15]
# Out:
#                          0               1            2               3  \
# 0           Commodity Name    Variety Name  Market Name  Arrivals(Qtls)
# 1                    Paddy  Common (Hamsa)   Narayanpet            27.6
# 2                  Grade-A        Suryapet          340            2019
# 3                  Grade-A          Bodhan          139            1888
# 4                  Grade-A         Korutla           10            2000
# 5            Grade-A (RNR)        Suryapet          445            2151
# 6   Grade-A (Samba Masuri)        Suryapet          170            2071
# 7   Grade-A (Samba Masuri)     Tirmalagiri           53            1500
# 8     Grade-A (Sonamasuri)      Narayanpet        334.8            1691
# 9     Grade-A (Sonamasuri)          Gadwal           40            1657
# 10           Grade-A(IR64)        Suryapet          115            1491
# 11           Grade-A(IR64)     Tirmalagiri           23            1371
# 12                   Maize          Common     Warangal            25.2
# 13                   Jowar           White   Narayanpet           24.99
# 14                Red Gram          Common     Suryapet              25
#
#           4        5                6                7
# 0   Maximum  Minimum            Model      Purchase By
# 1      1455     1446             1451  Private Traders
# 2      1211     1359  Private Traders              NaN
# 3      1888     1888  Private Traders              NaN
# 4      1940     1950  Private Traders              NaN
# 5      1359     1729  Private Traders              NaN
# 6      1414     1776  Private Traders              NaN
# 7      1465     1470  Private Traders              NaN
# 8      1211     1471  Private Traders              NaN
# 9      1539     1657  Private Traders              NaN
# 10     1251     1329  Private Traders              NaN
# 11     1359     1371  Private Traders              NaN
# 12     1857     1575             1679  Private Traders
# 13     2000     2000             2000  Private Traders
# 14     5965     3096             5292  Private Traders
